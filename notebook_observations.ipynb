# %% [markdown]
# # GRSW observations notebook

# %% [markdown]
# This notebook shows how to access the summary table of the observations data compiled for the GRSW workshop.
# It require to pull a python package to access easily the data stored on [DACE](https://dace.unige.ch/dashboard/)

# %% [markdown]
# ### Importing useful functions
#
# First we need to import the function needed for the notebook

# %%
from resonantstate.data_download  import get_metadata_observations, download_observations_samples
from resonantstate.analyse_samples import *
from resonantstate.ell2SFM import plot_ell2SFM

# %% [markdown]
# We can download the metatable to have a look on the available observations samples

# %%
dataframe_observations = get_metadata_observations()
dataframe_observations.head()
# Out:
#   planet_name star_name  analysis_id             contact_mail  default  \
# 0   K00972.01    K00972            0  darin_ragozzine@byu.edu        1
# 1   K00972.02    K00972            0  darin_ragozzine@byu.edu        1
# 2   K01239.01    K01239            0  darin_ragozzine@byu.edu        1
# 3   K01239.02    K01239            0  darin_ragozzine@byu.edu        1
# 4   K01884.01    K01884            0  darin_ragozzine@byu.edu        1
#
#    robustness  period_days  radius_planet_r_earth  mass_planet_m_earth  \
# 0          -1    13.119837               3.228469             0.064462
# 1          -1     7.821838               1.040388             0.459848
# 2          -1     0.783274               1.454645             7.688309
# 3          -1     3.174604               1.488855             8.795811
# 4          -1    23.096662               4.063375             8.459971
#
#    mass_star_m_sun  ...  eccentricity_prior         methods  instruments  \
# 0         1.602344  ...  uniform in sqrt(e)  photo-dynamics       Kepler
# 1         1.602344  ...  uniform in sqrt(e)  photo-dynamics       Kepler
# 2         0.965796  ...  uniform in sqrt(e)  photo-dynamics       Kepler
# 3         0.965796  ...  uniform in sqrt(e)  photo-dynamics       Kepler
# 4         0.832291  ...  uniform in sqrt(e)  photo-dynamics       Kepler
#
#      bibtex  code_used                         other_remarks  \
# 0  KMDC_TBD    PhoDyMM  See README.txt for more information.
# 1  KMDC_TBD    PhoDyMM  See README.txt for more information.
# 2  KMDC_TBD    PhoDyMM  See README.txt for more information.
# 3  KMDC_TBD    PhoDyMM  See README.txt for more information.
# 4  KMDC_TBD    PhoDyMM  See README.txt for more information.
#
#                                        metadata_file  additional_info  \
# 0  https://dace.unige.ch/downloads/resonant_state...
# 1  https://dace.unige.ch/downloads/resonant_state...
# 2  https://dace.unige.ch/downloads/resonant_state...
# 3  https://dace.unige.ch/downloads/resonant_state...
# 4  https://dace.unige.ch/downloads/resonant_state...
#
#                                          readme_file  \
# 0  https://dace.unige.ch/downloads/resonant_state...
# 1  https://dace.unige.ch/downloads/resonant_state...
# 2  https://dace.unige.ch/downloads/resonant_state...
# 3  https://dace.unige.ch/downloads/resonant_state...
# 4  https://dace.unige.ch/downloads/resonant_state...
#
#                                       url_of_samples
# 0  https://dace.unige.ch/downloads/resonant_state...
# 1  https://dace.unige.ch/downloads/resonant_state...
# 2  https://dace.unige.ch/downloads/resonant_state...
# 3  https://dace.unige.ch/downloads/resonant_state...
# 4  https://dace.unige.ch/downloads/resonant_state...
#
# [5 rows x 33 columns]

# %% [markdown]
# We can have a look on the available columns:

# %%
dataframe_observations.head(0).T
# Out:
# Empty DataFrame
# Columns: []
# Index: [planet_name, star_name, analysis_id, contact_mail, default, robustness, period_days, radius_planet_r_earth, mass_planet_m_earth, mass_star_m_sun, radius_star_r_sun, planet_star_mass_ratio, planet_star_radius_ratio, semi_major_axis_au, mean_longitude_deg, eccentricity, longitude_of_periastron_deg, inclination_deg, longitude_of_ascending_node_deg, initial_condition_date_BJD, nb_planets, gaia_id, mass_prior, eccentricity_prior, methods, instruments, bibtex, code_used, other_remarks, metadata_file, additional_info, readme_file, url_of_samples]

# %% [markdown]
# Let's look at the list of analysed systems:

# %%
dataframe_observations["star_name"].unique()
# Out:
# array(['K00972', 'K01239', 'K01884', 'K02093', 'K02357', 'K02421',
#        'K02449', 'K02554', 'K02610', 'K02696', 'K02840', 'K02949',
#        'K02972', 'K03029', 'K03083', 'K03111', 'K03196', 'K03209',
#        'K03340', 'K03341', 'K03395', 'K03401', 'K03420', 'K03462',
#        'K03495', 'K04021', 'K04136', 'K04149', 'K04287', 'K04307',
#        'K04421', 'K04435', 'K04504', 'K04526', 'K04535', 'K04541',
#        'K04567', 'K04577', 'K04647', 'K04657', 'K04700', 'K04773',
#        'K04782', 'K04846', 'K04871', 'K04896', 'K04913', 'K05007',
#        'K06093', 'K06103', 'K06120', 'K06178', 'K06182', 'K06191',
#        'K06209', 'K06245', 'K06259', 'K06355', 'K07117', 'K07685',
#        'Kepler-10', 'Kepler-100', 'Kepler-1006', 'Kepler-101',
#        'Kepler-1010', 'Kepler-1014', 'Kepler-102', 'Kepler-103',
#        'Kepler-1038', 'Kepler-104', 'Kepler-1042', 'Kepler-1047',
#        'Kepler-105', 'Kepler-1050', 'Kepler-1052', 'Kepler-1056',
#        'Kepler-106', 'Kepler-1065', 'Kepler-1067', 'Kepler-107',
#        'Kepler-1073', 'Kepler-108', 'Kepler-1085', 'Kepler-1086',
#        'Kepler-109', 'Kepler-1090', 'Kepler-1093', 'Kepler-1098',
#        'Kepler-11', 'Kepler-110', 'Kepler-112', 'Kepler-1126',
#        'Kepler-113', 'Kepler-1130', 'Kepler-1136', 'Kepler-114',
#        'Kepler-1142', 'Kepler-1143', 'Kepler-115', 'Kepler-1154',
#        'Kepler-116', 'Kepler-1162', 'Kepler-1165', 'Kepler-1166',
#        'Kepler-117', 'Kepler-1178', 'Kepler-118', 'Kepler-1181',
#        'Kepler-119', 'Kepler-1191', 'Kepler-120', 'Kepler-121',
#        'Kepler-1211', 'Kepler-122', 'Kepler-123', 'Kepler-1231',
#        'Kepler-1232', 'Kepler-1239', 'Kepler-124', 'Kepler-1243',
#        'Kepler-1245', 'Kepler-125', 'Kepler-1254', 'Kepler-126',
#        'Kepler-1266', 'Kepler-1267', 'Kepler-127', 'Kepler-1271',
#        'Kepler-1279', 'Kepler-128', 'Kepler-1280', 'Kepler-1285',
#        'Kepler-129', 'Kepler-1293', 'Kepler-130', 'Kepler-131',
#        'Kepler-1311', 'Kepler-1312', 'Kepler-1315', 'Kepler-1321',
#        'Kepler-1322', 'Kepler-1324', 'Kepler-133', 'Kepler-1330',
#        'Kepler-1333', 'Kepler-1336', 'Kepler-134', 'Kepler-1340',
#        'Kepler-135', 'Kepler-1350', 'Kepler-1359', 'Kepler-136',
#        'Kepler-1365', 'Kepler-137', 'Kepler-1370', 'Kepler-1371',
#        'Kepler-138', 'Kepler-1383', 'Kepler-1387', 'Kepler-1388',
#        'Kepler-139', 'Kepler-1396', 'Kepler-1398', 'Kepler-140',
#        'Kepler-1407', 'Kepler-141', 'Kepler-1419', 'Kepler-142',
#        'Kepler-143', 'Kepler-144', 'Kepler-145', 'Kepler-146',
#        'Kepler-1464', 'Kepler-147', 'Kepler-1471', 'Kepler-1474',
#        'Kepler-1475', 'Kepler-148', 'Kepler-1481', 'Kepler-1482',
#        'Kepler-1485', 'Kepler-1487', 'Kepler-149', 'Kepler-1491',
#        'Kepler-1497', 'Kepler-150', 'Kepler-1500', 'Kepler-1505',
#        'Kepler-1509', 'Kepler-151', 'Kepler-1511', 'Kepler-152',
#        'Kepler-1524', 'Kepler-153', 'Kepler-1530', 'Kepler-1538',
#        'Kepler-154', 'Kepler-1542', 'Kepler-1543', 'Kepler-1549',
#        'Kepler-155', 'Kepler-1552', 'Kepler-1558', 'Kepler-156',
#        'Kepler-1564', 'Kepler-1569', 'Kepler-157', 'Kepler-1576',
#        'Kepler-158', 'Kepler-1581', 'Kepler-1586', 'Kepler-159',
#        'Kepler-1597', 'Kepler-1598', 'Kepler-160', 'Kepler-1600',
#        'Kepler-161', 'Kepler-1610', 'Kepler-162', 'Kepler-163',
#        'Kepler-1632', 'Kepler-1639', 'Kepler-164', 'Kepler-1641',
#        'Kepler-1642', 'Kepler-1649', 'Kepler-165', 'Kepler-1659',
#        'Kepler-166', 'Kepler-1662', 'Kepler-1666', 'Kepler-1669',
#        'Kepler-168', 'Kepler-169', 'Kepler-1693', 'Kepler-1698',
#        'Kepler-170', 'Kepler-1703', 'Kepler-1705', 'Kepler-171',
#        'Kepler-1717', 'Kepler-172', 'Kepler-173', 'Kepler-174',
#        'Kepler-1744', 'Kepler-175', 'Kepler-1755', 'Kepler-1756',
#        'Kepler-1758', 'Kepler-176', 'Kepler-177', 'Kepler-178',
#        'Kepler-179', 'Kepler-18', 'Kepler-180', 'Kepler-1800',
#        'Kepler-1801', 'Kepler-1802', 'Kepler-1806', 'Kepler-181',
#        'Kepler-1810', 'Kepler-1814', 'Kepler-182', 'Kepler-1824',
#        'Kepler-183', 'Kepler-184', 'Kepler-1849', 'Kepler-185',
#        'Kepler-1859', 'Kepler-186', 'Kepler-1869', 'Kepler-187',
#        'Kepler-188', 'Kepler-1886', 'Kepler-189', 'Kepler-1893',
#        'Kepler-1894', 'Kepler-1899', 'Kepler-190', 'Kepler-1901',
#        'Kepler-1903', 'Kepler-1907', 'Kepler-191', 'Kepler-1915',
#        'Kepler-192', 'Kepler-1927', 'Kepler-193', 'Kepler-1930',
#        'Kepler-1939', 'Kepler-195', 'Kepler-1958', 'Kepler-196',
#        'Kepler-1962', 'Kepler-197', 'Kepler-1972', 'Kepler-1977',
#        'Kepler-1978', 'Kepler-198', 'Kepler-1980', 'Kepler-1983',
#        'Kepler-1984', 'Kepler-1985', 'Kepler-1987', 'Kepler-1988',
#        'Kepler-1989', 'Kepler-1990', 'Kepler-1991', 'Kepler-1992',
#        'Kepler-1993', 'Kepler-1994', 'Kepler-1995', 'Kepler-1996',
#        'Kepler-1999', 'Kepler-20', 'Kepler-200', 'Kepler-201',
#        'Kepler-202', 'Kepler-203', 'Kepler-204', 'Kepler-205',
#        'Kepler-206', 'Kepler-207', 'Kepler-208', 'Kepler-209',
#        'Kepler-210', 'Kepler-211', 'Kepler-212', 'Kepler-213',
#        'Kepler-214', 'Kepler-215', 'Kepler-216', 'Kepler-217',
#        'Kepler-218', 'Kepler-219', 'Kepler-220', 'Kepler-221',
#        'Kepler-222', 'Kepler-223', 'Kepler-224', 'Kepler-225',
#        'Kepler-226', 'Kepler-227', 'Kepler-228', 'Kepler-229',
#        'Kepler-23', 'Kepler-230', 'Kepler-231', 'Kepler-232',
#        'Kepler-233', 'Kepler-234', 'Kepler-235', 'Kepler-236',
#        'Kepler-237', 'Kepler-238', 'Kepler-239', 'Kepler-24',
#        'Kepler-240', 'Kepler-241', 'Kepler-243', 'Kepler-244',
#        'Kepler-245', 'Kepler-246', 'Kepler-247', 'Kepler-248',
#        'Kepler-249', 'Kepler-25', 'Kepler-250', 'Kepler-251',
#        'Kepler-252', 'Kepler-253', 'Kepler-254', 'Kepler-255',
#        'Kepler-256', 'Kepler-257', 'Kepler-258', 'Kepler-259',
#        'Kepler-26', 'Kepler-260', 'Kepler-261', 'Kepler-262',
#        'Kepler-263', 'Kepler-264', 'Kepler-265', 'Kepler-266',
#        'Kepler-267', 'Kepler-268', 'Kepler-269', 'Kepler-27',
#        'Kepler-270', 'Kepler-271', 'Kepler-272', 'Kepler-273',
#        'Kepler-274', 'Kepler-276', 'Kepler-277', 'Kepler-278',
#        'Kepler-279', 'Kepler-28', 'Kepler-280', 'Kepler-281',
#        'Kepler-282', 'Kepler-283', 'Kepler-284', 'Kepler-285',
#        'Kepler-286', 'Kepler-287', 'Kepler-288', 'Kepler-289',
#        'Kepler-29', 'Kepler-290', 'Kepler-291', 'Kepler-292',
#        'Kepler-293', 'Kepler-294', 'Kepler-295', 'Kepler-296',
#        'Kepler-297', 'Kepler-298', 'Kepler-299', 'Kepler-30',
#        'Kepler-300', 'Kepler-301', 'Kepler-302', 'Kepler-303',
#        'Kepler-304', 'Kepler-305', 'Kepler-306', 'Kepler-307',
#        'Kepler-308', 'Kepler-309', 'Kepler-31', 'Kepler-310',
#        'Kepler-311', 'Kepler-314', 'Kepler-315', 'Kepler-316',
#        'Kepler-317', 'Kepler-318', 'Kepler-319', 'Kepler-32',
#        'Kepler-320', 'Kepler-321', 'Kepler-322', 'Kepler-323',
#        'Kepler-324', 'Kepler-325', 'Kepler-326', 'Kepler-327',
#        'Kepler-328', 'Kepler-329', 'Kepler-33', 'Kepler-330',
#        'Kepler-331', 'Kepler-332', 'Kepler-333', 'Kepler-334',
#        'Kepler-335', 'Kepler-336', 'Kepler-337', 'Kepler-338',
#        'Kepler-339', 'Kepler-340', 'Kepler-341', 'Kepler-342',
#        'Kepler-343', 'Kepler-344', 'Kepler-345', 'Kepler-346',
#        'Kepler-347', 'Kepler-348', 'Kepler-349', 'Kepler-350',
#        'Kepler-351', 'Kepler-352', 'Kepler-353', 'Kepler-354',
#        'Kepler-355', 'Kepler-356', 'Kepler-357', 'Kepler-358',
#        'Kepler-359', 'Kepler-36', 'Kepler-360', 'Kepler-361',
#        'Kepler-362', 'Kepler-363', 'Kepler-364', 'Kepler-365',
#        'Kepler-366', 'Kepler-367', 'Kepler-368', 'Kepler-369',
#        'Kepler-37', 'Kepler-370', 'Kepler-371', 'Kepler-372',
#        'Kepler-373', 'Kepler-374', 'Kepler-375', 'Kepler-376',
#        'Kepler-377', 'Kepler-378', 'Kepler-379', 'Kepler-380',
#        'Kepler-381', 'Kepler-382', 'Kepler-383', 'Kepler-384',
#        'Kepler-385', 'Kepler-386', 'Kepler-387', 'Kepler-389',
#        'Kepler-390', 'Kepler-391', 'Kepler-392', 'Kepler-393',
#        'Kepler-394', 'Kepler-396', 'Kepler-397', 'Kepler-398',
#        'Kepler-399', 'Kepler-400', 'Kepler-402', 'Kepler-403',
#        'Kepler-405', 'Kepler-406', 'Kepler-414', 'Kepler-415',
#        'Kepler-416', 'Kepler-417', 'Kepler-418', 'Kepler-419',
#        'Kepler-42', 'Kepler-430', 'Kepler-431', 'Kepler-436',
#        'Kepler-441', 'Kepler-444', 'Kepler-445', 'Kepler-446',
#        'Kepler-449', 'Kepler-450', 'Kepler-458', 'Kepler-460',
#        'Kepler-462', 'Kepler-466', 'Kepler-48', 'Kepler-487', 'Kepler-49',
#        'Kepler-495', 'Kepler-50', 'Kepler-501', 'Kepler-505',
#        'Kepler-508', 'Kepler-51', 'Kepler-511', 'Kepler-515', 'Kepler-52',
#        'Kepler-520', 'Kepler-521', 'Kepler-524', 'Kepler-525',
#        'Kepler-526', 'Kepler-528', 'Kepler-529', 'Kepler-53',
#        'Kepler-534', 'Kepler-54', 'Kepler-549', 'Kepler-55', 'Kepler-551',
#        'Kepler-553', 'Kepler-559', 'Kepler-56', 'Kepler-561', 'Kepler-57',
#        'Kepler-58', 'Kepler-589', 'Kepler-59', 'Kepler-595', 'Kepler-596',
#        'Kepler-598', 'Kepler-60', 'Kepler-604', 'Kepler-605',
#        'Kepler-607', 'Kepler-610', 'Kepler-616', 'Kepler-618',
#        'Kepler-619', 'Kepler-62', 'Kepler-621', 'Kepler-624',
#        'Kepler-625', 'Kepler-633', 'Kepler-634', 'Kepler-635',
#        'Kepler-647', 'Kepler-65', 'Kepler-653', 'Kepler-656',
#        'Kepler-657', 'Kepler-662', 'Kepler-675', 'Kepler-68', 'Kepler-69',
#        'Kepler-712', 'Kepler-716', 'Kepler-722', 'Kepler-730',
#        'Kepler-732', 'Kepler-745', 'Kepler-750', 'Kepler-755',
#        'Kepler-756', 'Kepler-758', 'Kepler-760', 'Kepler-763',
#        'Kepler-764', 'Kepler-769', 'Kepler-771', 'Kepler-783',
#        'Kepler-784', 'Kepler-79', 'Kepler-80', 'Kepler-804', 'Kepler-81',
#        'Kepler-813', 'Kepler-822', 'Kepler-825', 'Kepler-83',
#        'Kepler-834', 'Kepler-84', 'Kepler-844', 'Kepler-85', 'Kepler-853',
#        'Kepler-859', 'Kepler-864', 'Kepler-865', 'Kepler-87',
#        'Kepler-876', 'Kepler-879', 'Kepler-880', 'Kepler-887',
#        'Kepler-89', 'Kepler-896', 'Kepler-9', 'Kepler-90', 'Kepler-907',
#        'Kepler-913', 'Kepler-92', 'Kepler-920', 'Kepler-937',
#        'Kepler-948', 'Kepler-951', 'Kepler-953', 'Kepler-960',
#        'Kepler-967', 'Kepler-968', 'Kepler-969', 'Kepler-972',
#        'Kepler-974', 'Kepler-975', 'Kepler-985', 'Kepler-990', 'SOL',
#        'TOI-1130', 'TOI-1136', 'TOI-1338', 'TOI-178', 'TRAPPIST-1',
#        'WASP-148', 'WASP-47'], dtype=object)

# %% [markdown]
# Lets keep only the analysis of the Kepler-51 systems:

# %%
dataframe_observations_Kep51 = dataframe_observations[dataframe_observations["star_name"].isin(['Kepler-51'])]
dataframe_observations_Kep51.head(100)
# Out:
#       planet_name  star_name  analysis_id                   contact_mail  \
# 1645  Kepler-51 b  Kepler-51            0          shadden1107@gmail.com
# 1646  Kepler-51 c  Kepler-51            0          shadden1107@gmail.com
# 1647  Kepler-51 d  Kepler-51            0          shadden1107@gmail.com
# 1648  Kepler-51 b  Kepler-51            1          shadden1107@gmail.com
# 1649  Kepler-51 c  Kepler-51            1          shadden1107@gmail.com
# 1650  Kepler-51 d  Kepler-51            1          shadden1107@gmail.com
# 1651  Kepler-51 b  Kepler-51            2  kmasuda@ess.sci.osaka-u.ac.jp
# 1652  Kepler-51 d  Kepler-51            2  kmasuda@ess.sci.osaka-u.ac.jp
# 1653  kepler-51 c  Kepler-51            2  kmasuda@ess.sci.osaka-u.ac.jp
# 1654  Kepler-51 b  Kepler-51            3  kmasuda@ess.sci.osaka-u.ac.jp
# 1655  Kepler-51 d  Kepler-51            3  kmasuda@ess.sci.osaka-u.ac.jp
# 1656  Kepler-51 e  Kepler-51            3  kmasuda@ess.sci.osaka-u.ac.jp
# 1657  kepler-51 c  Kepler-51            3  kmasuda@ess.sci.osaka-u.ac.jp
# 1658  Kepler-51 b  Kepler-51            4  kmasuda@ess.sci.osaka-u.ac.jp
# 1659  Kepler-51 d  Kepler-51            4  kmasuda@ess.sci.osaka-u.ac.jp
# 1660  Kepler-51 e  Kepler-51            4  kmasuda@ess.sci.osaka-u.ac.jp
# 1661  kepler-51 c  Kepler-51            4  kmasuda@ess.sci.osaka-u.ac.jp
# 1662  Kepler-51 b  Kepler-51            5        darin_ragozzine@byu.edu
# 1663  Kepler-51 c  Kepler-51            5        darin_ragozzine@byu.edu
# 1664  Kepler-51 d  Kepler-51            5        darin_ragozzine@byu.edu
#
#       default  robustness  period_days  radius_planet_r_earth  \
# 1645        1           1    45.153994               7.601707
# 1646        1           1    85.312028               9.637988
# 1647        1           1   130.186048              10.397749
# 1648        0           1    45.154075               7.601707
# 1649        0           1    85.311249               9.637988
# 1650        0           1   130.186722              10.397749
# 1651        0           0    45.154293               6.927440
# 1652        0           1   130.194122               9.394748
# 1653        0           1    85.317904               5.693787
# 1654        0          -1    45.154105               6.927440
# 1655        0          -1   130.191524               9.394748
# 1656        0          -1   256.842231              -1.000000
# 1657        0          -1    85.316003               5.693787
# 1658        0          -1    45.153965               6.927440
# 1659        0          -1   130.213963               9.394748
# 1660        0          -1   264.392289              -1.000000
# 1661        0          -1    85.326815               5.693787
# 1662        1          -1    45.157689               6.146654
# 1663        1          -1    85.327885               5.150027
# 1664        1          -1   130.193488               8.368968
#
#       mass_planet_m_earth  mass_star_m_sun  ...  eccentricity_prior  \
# 1645             2.541467         1.040000  ...             uniform
# 1646             3.889650         1.040000  ...             uniform
# 1647             6.423000         1.040000  ...             uniform
# 1648             3.736545         1.040000  ...         log-uniform
# 1649             4.356044         1.040000  ...         log-uniform
# 1650             7.252768         1.040000  ...         log-uniform
# 1651             3.586360         0.960000  ...             uniform
# 1652             5.549486         0.960000  ...             uniform
# 1653             4.322407         0.960000  ...             uniform
# 1654             3.233482         0.960000  ...             uniform
# 1655             5.563730         0.960000  ...             uniform
# 1656             3.565588         0.960000  ...             uniform
# 1657             5.635446         0.960000  ...             uniform
# 1658             6.258480         0.960000  ...             uniform
# 1659             6.539622         0.960000  ...             uniform
# 1660             5.281757         0.960000  ...             uniform
# 1661             6.077580         0.960000  ...             uniform
# 1662             2.707864         0.935582  ...  uniform in sqrt(e)
# 1663             4.113113         0.935582  ...  uniform in sqrt(e)
# 1664             6.352287         0.935582  ...  uniform in sqrt(e)
#
#               methods                                        instruments  \
# 1645  extracted times                                             Kepler
# 1646  extracted times                                             Kepler
# 1647  extracted times                                             Kepler
# 1648  extracted times                                             Kepler
# 1649  extracted times                                             Kepler
# 1650  extracted times                                             Kepler
# 1651              TTV                                        Kepler, HST
# 1652              TTV                                        Kepler, HST
# 1653              TTV                                        Kepler, HST
# 1654              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1655              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1656              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1657              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1658              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1659              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1660              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1661              TTV  Kepler, HST, TESS, JWST, MuSCAT2, MuSCAT3, APO...
# 1662   photo-dynamics                                             Kepler
# 1663   photo-dynamics                                             Kepler
# 1664   photo-dynamics                                             Kepler
#
#                    bibtex                             code_used  \
# 1645  2017AJ....154....5H                   2014ApJ...787..132D
# 1646  2017AJ....154....5H                   2014ApJ...787..132D
# 1647  2017AJ....154....5H                   2014ApJ...787..132D
# 1648  2017AJ....154....5H                   2014ApJ...787..132D
# 1649  2017AJ....154....5H                   2014ApJ...787..132D
# 1650  2017AJ....154....5H                   2014ApJ...787..132D
# 1651  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1652  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1653  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1654  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1655  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1656  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1657  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1658  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1659  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1660  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1661  2024AJ....168..294M  https://github.com/kemasuda/jnkepler
# 1662             KMDC_TBD                               PhoDyMM
# 1663             KMDC_TBD                               PhoDyMM
# 1664             KMDC_TBD                               PhoDyMM
#
#                                           other_remarks  \
# 1645  Last column value, dt, specifies initial condi...
# 1646  Last column value, dt, specifies initial condi...
# 1647  Last column value, dt, specifies initial condi...
# 1648  Last column value, dt, specifies initial condi...
# 1649  Last column value, dt, specifies initial condi...
# 1650  Last column value, dt, specifies initial condi...
# 1651  Posterior samples from a three-planet fit to t...
# 1652  Posterior samples from a three-planet fit to t...
# 1653  Posterior samples from a three-planet fit to t...
# 1654  Posterior samples from a four-planet fit to tr...
# 1655  Posterior samples from a four-planet fit to tr...
# 1656  Posterior samples from a four-planet fit to tr...
# 1657  Posterior samples from a four-planet fit to tr...
# 1658  Posterior samples from a four-planet fit to tr...
# 1659  Posterior samples from a four-planet fit to tr...
# 1660  Posterior samples from a four-planet fit to tr...
# 1661  Posterior samples from a four-planet fit to tr...
# 1662               See README.txt for more information.
# 1663               See README.txt for more information.
# 1664               See README.txt for more information.
#
#                                           metadata_file  additional_info  \
# 1645  https://dace.unige.ch/downloads/resonant_state...
# 1646  https://dace.unige.ch/downloads/resonant_state...
# 1647  https://dace.unige.ch/downloads/resonant_state...
# 1648  https://dace.unige.ch/downloads/resonant_state...
# 1649  https://dace.unige.ch/downloads/resonant_state...
# 1650  https://dace.unige.ch/downloads/resonant_state...
# 1651  https://dace.unige.ch/downloads/resonant_state...
# 1652  https://dace.unige.ch/downloads/resonant_state...
# 1653  https://dace.unige.ch/downloads/resonant_state...
# 1654  https://dace.unige.ch/downloads/resonant_state...
# 1655  https://dace.unige.ch/downloads/resonant_state...
# 1656  https://dace.unige.ch/downloads/resonant_state...
# 1657  https://dace.unige.ch/downloads/resonant_state...
# 1658  https://dace.unige.ch/downloads/resonant_state...
# 1659  https://dace.unige.ch/downloads/resonant_state...
# 1660  https://dace.unige.ch/downloads/resonant_state...
# 1661  https://dace.unige.ch/downloads/resonant_state...
# 1662  https://dace.unige.ch/downloads/resonant_state...
# 1663  https://dace.unige.ch/downloads/resonant_state...
# 1664  https://dace.unige.ch/downloads/resonant_state...
#
#                                             readme_file  \
# 1645  https://dace.unige.ch/downloads/resonant_state...
# 1646  https://dace.unige.ch/downloads/resonant_state...
# 1647  https://dace.unige.ch/downloads/resonant_state...
# 1648  https://dace.unige.ch/downloads/resonant_state...
# 1649  https://dace.unige.ch/downloads/resonant_state...
# 1650  https://dace.unige.ch/downloads/resonant_state...
# 1651  https://dace.unige.ch/downloads/resonant_state...
# 1652  https://dace.unige.ch/downloads/resonant_state...
# 1653  https://dace.unige.ch/downloads/resonant_state...
# 1654  https://dace.unige.ch/downloads/resonant_state...
# 1655  https://dace.unige.ch/downloads/resonant_state...
# 1656  https://dace.unige.ch/downloads/resonant_state...
# 1657  https://dace.unige.ch/downloads/resonant_state...
# 1658  https://dace.unige.ch/downloads/resonant_state...
# 1659  https://dace.unige.ch/downloads/resonant_state...
# 1660  https://dace.unige.ch/downloads/resonant_state...
# 1661  https://dace.unige.ch/downloads/resonant_state...
# 1662  https://dace.unige.ch/downloads/resonant_state...
# 1663  https://dace.unige.ch/downloads/resonant_state...
# 1664  https://dace.unige.ch/downloads/resonant_state...
#
#                                          url_of_samples
# 1645  https://dace.unige.ch/downloads/resonant_state...
# 1646  https://dace.unige.ch/downloads/resonant_state...
# 1647  https://dace.unige.ch/downloads/resonant_state...
# 1648  https://dace.unige.ch/downloads/resonant_state...
# 1649  https://dace.unige.ch/downloads/resonant_state...
# 1650  https://dace.unige.ch/downloads/resonant_state...
# 1651  https://dace.unige.ch/downloads/resonant_state...
# 1652  https://dace.unige.ch/downloads/resonant_state...
# 1653  https://dace.unige.ch/downloads/resonant_state...
# 1654  https://dace.unige.ch/downloads/resonant_state...
# 1655  https://dace.unige.ch/downloads/resonant_state...
# 1656  https://dace.unige.ch/downloads/resonant_state...
# 1657  https://dace.unige.ch/downloads/resonant_state...
# 1658  https://dace.unige.ch/downloads/resonant_state...
# 1659  https://dace.unige.ch/downloads/resonant_state...
# 1660  https://dace.unige.ch/downloads/resonant_state...
# 1661  https://dace.unige.ch/downloads/resonant_state...
# 1662  https://dace.unige.ch/downloads/resonant_state...
# 1663  https://dace.unige.ch/downloads/resonant_state...
# 1664  https://dace.unige.ch/downloads/resonant_state...
#
# [20 rows x 33 columns]

# %% [markdown]
# Let's download the samples from these systems. If a path is given, it saves the samples into the given directory.

# %%
#download_destination_path = "downloaded_observtions_samples/"
download_destination_path = None
df_list = download_observations_samples(dataframe_observations_Kep51, download_destination_path)

# %% [markdown]
# The downloaded samples are returned as a list. Each element of the list is a dictionnary containing informations on the downloaded sample and the sample itself.
#
# Looking at the first element of the list, we can see its structure:

# %%
for k,v in df_list[0].items():
    if k == "sample":
        print(f"{k}:\t...")
    else:
        print(f"{k}:\t{v}")
# Out:
# sample_name:	Kepler-51_0
# planets_list:	['Kepler-51 b', 'Kepler-51 c', 'Kepler-51 d']
# code:	2014ApJ...787..132D
# bibtex:	2017AJ....154....5H
# contact_email:	shadden1107@gmail.com
# sample:	...
# readme:	Last column value, 'dt', specifies initial condition date as 'BJD 2454900+dt'

# %% [markdown]
# Let's have a look at the samples from the first analysis:

# %%
df = df_list[0]['sample']
df.head()
# Out:
#    sample_index  mean_longitude_deg_0  period_days_0       k_0       h_0  \
# 0           0.0                  54.0      45.154506 -0.009102 -0.064021
# 1           1.0                  54.0      45.154496 -0.005337 -0.026201
# 2           2.0                  54.0      45.153737 -0.021506 -0.048127
# 3           3.0                  54.0      45.154237 -0.016637 -0.024374
# 4           4.0                  54.0      45.153849 -0.034157 -0.047033
#
#    inclination_deg_0  longitude_of_ascending_node_deg_0  \
# 0               90.0                                0.0
# 1               90.0                                0.0
# 2               90.0                                0.0
# 3               90.0                                0.0
# 4               90.0                                0.0
#
#    mass_planet_star_ratio_0  radius_planet_star_ratio_0  mean_longitude_deg_1  \
# 0              6.533025e-08                     0.07414            213.944863
# 1              1.785980e-05                     0.07414            215.182850
# 2              5.341762e-06                     0.07414            211.174425
# 3              1.247548e-05                     0.07414            214.720439
# 4              3.849589e-06                     0.07414            213.472991
#
#    ...  period_days_2       k_2       h_2  inclination_deg_2  \
# 0  ...     130.187116  0.010685 -0.033310               90.0
# 1  ...     130.184333 -0.000353  0.001167               90.0
# 2  ...     130.183964  0.020317 -0.026003               90.0
# 3  ...     130.186229 -0.001905 -0.001907               90.0
# 4  ...     130.185711  0.000157 -0.000119               90.0
#
#    longitude_of_ascending_node_deg_2  mass_planet_star_ratio_2  \
# 0                                0.0                  0.000015
# 1                                0.0                  0.000028
# 2                                0.0                  0.000019
# 3                                0.0                  0.000025
# 4                                0.0                  0.000019
#
#    radius_planet_star_ratio_2  mass_star_m_sun  radius_star_r_sun  \
# 0                     0.10141             1.04               0.94
# 1                     0.10141             1.04               0.94
# 2                     0.10141             1.04               0.94
# 3                     0.10141             1.04               0.94
# 4                     0.10141             1.04               0.94
#
#    BJD2454900+dt
# 0      87.457602
# 1      87.517978
# 2      87.274171
# 3      87.351368
# 4      87.087637
#
# [5 rows x 28 columns]

# %% [markdown]
# You can save the dataframe of this sample as a csv file for future analysis:

# %%
#destination_path = 'your_path_to_file/'
#sample_name = df_list[0]['sample_name'] 
#filename = destination_path + sample_name + '.csv'
#df.to_csv(filename, index=False)

# %% [markdown]
# Let's say you want to plot a mass-period diagram for a planet. You can directly extract each column from the header of the dataframe. Remember that planet indexing starts from 0.

# %%
n_planet = 0

mass = df[f'mass_planet_star_ratio_{n_planet}']
period = df[f'period_days_{n_planet}']

plt.figure()
plt.scatter(mass, period, alpha=0.1)
plt.xlabel('Mp/M*')
plt.ylabel('P (d)')
plt.title(f'planet {n_planet}')
plt.show()

# %% [markdown]
# Now comment out the following cell and try plotting the mass-eccentricity diagram:

# %%
#n_planet = 0
#
#mass = df[f'mass_planet_star_ratio_{n_planet}']
#
#plt.figure()
#plt.scatter(mass, ecc, alpha=0.1)
#plt.xlabel('Mp/M*')
#plt.ylabel('e')
#plt.title(f'planet {n_planet}')
#plt.show()

# %% [markdown]
# ### Analysis part 1: examples

# %% [markdown]
# Perhaps you might be more interested in comparing the samples for each planet across different analyses.
#
# We have prepared a few useful functions to make histograms and scatter plots of the different parameters. These functions loop over each analysis in your selected list of dictionaries and creates separate subplots for each planet, allowing you to compare the samples for each planet across different analyses.

# %% [markdown]
# You can directly plot the following parameters:
# - **"period"**      (in days)
# - **"k"**           (ecos(varpi))
# - **"h"**           (esin(varpi))
# - **"incl"**        (inclination in deg)
# - **"omega"**       (longitude of ascending node in deg)
# - **"mass"**        (in stellar mass)
# - **"radius"**      (in stellar radii)
# - **"lambda"**      (mean longitude in deg)
#
# You can also extract the following derived parameters:
# - **"ecc"**         (eccentricity)
# - **"varpi"**       (longitude of pericenter in deg)
# - **"density"**     (in stellar density)

# %% [markdown]
# Let's first make **histograms** comparing the *mass posteriors* for each planet.

# %%
plot_histograms(df_list, param='mass', units='star')

# %% [markdown]
# Let's convert the units to something more intuitive.
#
# Valid units are: **"star"** (default), **"sun"**, **"earth"**, **"jup"**, or **"SI"**
#
# Unit conversion applies to parameters *"mass"*, *"radius"*, or *"density"*
#
# Try changing the units in the above histograms.
#
# Let's now make **scatter plots** of the different parameters. We can also slice the list of dictionaries to consider a subset of the analyses.

# %%
plot_samples(df_list[:-1], x_param='period', y_param='mass', units='earth')

# %% [markdown]
# Try making a **period-density** plot for the *first three analyses* in your list, with the density in **SI units**:

# %%
#plot_samples()

# %% [markdown]
# We might also be interested in the posterior distributions of **consecutive planets**:

# %%
plot_consecutive_planets(df_list, 'mass', units='earth')

# %% [markdown]
# We can also compare the **period ratios** between adjacent planets:

# %%
compare_period_ratios(df_list[:-1])

# %% [markdown]
# Let's now look at the **TRAPPIST-1 system**. Search and download the samples into a list of dictionaries as before.

# %%
#dataframe_observations_TRP1 =

# %% [markdown]
# Have a go at visualising the different parameters of the samples as before.

# %%
# your plots here

# %% [markdown]
# ### Analysis part 2: Second Fundamental Model of Resonance

# %% [markdown]
# For the next part we will be plotting the elliptic elements of the **Kepler-54** system into the *Second Fundamental Model* of resonance.
#
# Let's start by looking at just one of the samples.

# %%
dataframe_observations_Kep54 = dataframe_observations[dataframe_observations["star_name"].isin(['Kepler-54'])]
df_list_Kep54 = download_observations_samples(dataframe_observations_Kep54, download_destination_path)

samples = df_list_Kep54[2]['sample']
samples.head()
# Out:
#    sample_index  mean_longitude_deg_0  period_days_0       k_0       h_0  \
# 0           0.0            173.143899       8.011398  0.037330  0.072483
# 1           1.0           -179.935668       8.011400 -0.025893  0.016049
# 2           2.0            177.504088       8.011540 -0.003051  0.024661
# 3           3.0            178.030062       8.011495 -0.008226  0.021331
# 4           4.0           -175.629953       8.011458 -0.065789  0.054299
#
#    inclination_deg_0  longitude_of_ascending_node_deg_0  \
# 0          89.256031                       7.466398e-17
# 1          89.359722                       5.336995e-17
# 2          89.200918                       1.404573e-17
# 3          89.216676                       1.413979e-17
# 4          89.748860                       2.810327e-17
#
#    mass_planet_star_ratio_0  radius_planet_star_ratio_0  mean_longitude_deg_1  \
# 0                  0.000020                    0.033381           -132.194488
# 1                  0.000021                    0.032707           -126.499258
# 2                  0.000017                    0.033494           -128.791286
# 3                  0.000018                    0.032339           -128.189253
# 4                  0.000018                    0.032034           -123.077205
#
#    period_days_1       k_1       h_1  inclination_deg_1  \
# 0      12.071224  0.031173  0.041998          89.301563
# 1      12.071326 -0.019758 -0.003030          89.344849
# 2      12.070676  0.000663  0.001147          89.406280
# 3      12.070817 -0.003605 -0.001559          89.547602
# 4      12.070969 -0.049517  0.025393          89.453155
#
#    longitude_of_ascending_node_deg_1  mass_planet_star_ratio_1  \
# 0                      -7.664898e-07                  0.000013
# 1                       2.881801e-07                  0.000014
# 2                      -3.186814e-06                  0.000012
# 3                      -5.279319e-06                  0.000011
# 4                       5.206028e-06                  0.000012
#
#    radius_planet_star_ratio_1  mass_star_m_sun  radius_star_r_sun
# 0                    0.029761         0.461210              0.522
# 1                    0.029435         0.517523              0.522
# 2                    0.029653         0.516911              0.522
# 3                    0.029216         0.496470              0.522
# 4                    0.029509         0.525787              0.522

# %%
plot_ell2SFM(samples,                       # data to be plotted (dataframe, dictionary, or list of dicts)
             planet_pairs=[[0,1]],          # pairs of planets to be considered
             resonances=[2],                 # resonance of the corresponding pair (p such that resonance is p:p+1)
             colors=[['green']],            # list of colors to be considered for each pair in each analysis
             delta_lim=(-3,5),              # limits of the x-axis
             X_lim=(-5,5)                   # limits of the y-axis
             )

# %% [markdown]
# Let's compare the samples for this pair of planets from *two separate analyses*:

# %%
plot_ell2SFM(df_list_Kep54[1:3],            # this time we are plotting two of the dictionaries in the list
             planet_pairs=[[0,1]],          # pairs of planets to be considered
             resonances=[2],                 # resonance of the corresponding pair (p such that resonance is p:p+1)
             colors=[['green'],['blue']],   # here we give each analysis its own list of colours
             delta_lim=(-3,5),              # limits of the x-axis
             X_lim=(-5,5)                   # limits of the y-axis
             )

# %% [markdown]
# Now let's go back to your list of samples for the **TRAPPIST-1 system**. This list should contain the dictionary for one analysis.
#
# Start by extracting one dataframe of samples and try making the plot for the planet pairs that are in 1st order mean motion resonance.

# %%
#samples_TRP1 =

# %%
#plot_ell2SFM(samples_TRP1,                      
#             planet_pairs=[[],[]],            
#             resonances=[],                     
#             colors=[['green', 'blue']],       
#             delta_lim=(-3,5),                 
#             X_lim=(-5,5)                      
#             )
